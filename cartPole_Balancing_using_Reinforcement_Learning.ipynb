# %%
# !pip install gymnasium
# !pip install pygame
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (2.6.1)

# %%
import gymnasium as gym
import numpy as np
import time

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %%
state, info = env.reset()

print("Initial State:")
print(state)
# Out:
# Initial State:
# [-0.02271939 -0.03758307 -0.04228636 -0.00462709]

# %%
print("Action Space:", env.action_space)

print("Observation Space:", env.observation_space)
# Out:
# Action Space: Discrete(2)
# Observation Space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %%
episodes = 3

for episode in range(episodes):

    state, info = env.reset()
    done = False
    score = 0

    while not done:

        action = env.action_space.sample()

        next_state, reward, terminated, truncated, info = env.step(action)

        done = terminated or truncated

        score += reward

        state = next_state

    print(f"Episode {episode+1} Score: {score}")
# Out:
# Episode 1 Score: 13.0
# Episode 2 Score: 19.0
# Episode 3 Score: 12.0

# %%
episodes = 5

for episode in range(episodes):

    state, info = env.reset()
    done = False
    score = 0

    while not done:

        pole_position = state[2]

        if pole_position < 0:
            action = 0
        else:
            action = 1

        next_state, reward, terminated, truncated, info = env.step(action)

        done = terminated or truncated

        score += reward

        state = next_state

    print(f"AI Episode {episode+1} Score: {score}")
# Out:
# AI Episode 1 Score: 58.0
# AI Episode 2 Score: 38.0
# AI Episode 3 Score: 34.0
# AI Episode 4 Score: 41.0
# AI Episode 5 Score: 31.0

# %%
print("CartPole Reinforcement Learning Project Completed Successfully 🚀")
# Out:
# CartPole Reinforcement Learning Project Completed Successfully 🚀

# %%
env.close()
